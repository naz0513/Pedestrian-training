# %%
import pandas as pd
import torch
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("/Users/anzhunie/Desktop/local_Pedestrian_Training/entire_dataset_with_cluster_masked.csv")
df = df.dropna(subset=['ID'])

# %%
traj_length = 15
grouped = df.groupby(['ID', 'Trajectory'])
trajectory_features = ['Positionx', 'Positiony', 'Distance', 
                       'Speed', 'Speed Change', 'Direction', 'Direction Change']

# %%
data = []
total_segments = 0

for (pid, traj_id), group in grouped:
    group = group.sort_values(by='Time')

    if group.shape[0] < traj_length:
        continue
    

    num_segments = len(group) - traj_length + 1
    total_segments += num_segments
    print(f"ID {pid}, Trajectory {traj_id}: {num_segments} segments")

print(f"TOTAL SEGMENTS GENERATED: {total_segments}")
# Out:
# ID 40.0, Trajectory 3.0: 9 segments
# ID 40.0, Trajectory 4.0: 6 segments
# ID 40.0, Trajectory 6.0: 2 segments
# ID 40.0, Trajectory 8.0: 6 segments
# ID 40.0, Trajectory 9.0: 29 segments
# ID 40.0, Trajectory 16.0: 11 segments
# ID 41.0, Trajectory 3.0: 11 segments
# ID 41.0, Trajectory 6.0: 3 segments
# ID 41.0, Trajectory 7.0: 8 segments
# ID 41.0, Trajectory 8.0: 5 segments
# ID 41.0, Trajectory 9.0: 1 segments
# ID 41.0, Trajectory 10.0: 8 segments
# ID 41.0, Trajectory 11.0: 3 segments
# ID 41.0, Trajectory 12.0: 6 segments
# ID 41.0, Trajectory 13.0: 5 segments
# ID 41.0, Trajectory 14.0: 1 segments
# ID 41.0, Trajectory 15.0: 2 segments
# ID 41.0, Trajectory 16.0: 2 segments
# ID 41.0, Trajectory 17.0: 1 segments
# ID 41.0, Trajectory 20.0: 2 segments
# ID 41.0, Trajectory 21.0: 2 segments
# ID 41.0, Trajectory 22.0: 2 segments
# ID 41.0, Trajectory 24.0: 2 segments
# ID 41.0, Trajectory 25.0: 6 segments
# ID 41.0, Trajectory 26.0: 2 segments
# ID 43.0, Trajectory 3.0: 3 segments
# ID 43.0, Trajectory 4.0: 1 segments
# ID 43.0, Trajectory 6.0: 3 segments
# ID 43.0, Trajectory 10.0: 3 segments
# ID 43.0, Trajectory 11.0: 2 segments
# ID 43.0, Trajectory 12.0: 3 segments
# ID 43.0, Trajectory 13.0: 5 segments
# ID 43.0, Trajectory 14.0: 3 segments
# ID 43.0, Trajectory 17.0: 4 segments
# ID 43.0, Trajectory 22.0: 2 segments
# ID 43.0, Trajectory 25.0: 3 segments
# ID 45.0, Trajectory 4.0: 2 segments
# ID 45.0, Trajectory 7.0: 3 segments
# ID 45.0, Trajectory 14.0: 6 segments
# ID 45.0, Trajectory 23.0: 20 segments
# ID 45.0, Trajectory 28.0: 1 segments
# ID 45.0, Trajectory 35.0: 1 segments
# ID 50.0, Trajectory 2.0: 15 segments
# ID 50.0, Trajectory 3.0: 11 segments
# ID 50.0, Trajectory 4.0: 35 segments
# ID 50.0, Trajectory 5.0: 24 segments
# ID 50.0, Trajectory 6.0: 18 segments
# ID 50.0, Trajectory 7.0: 15 segments
# ID 50.0, Trajectory 20.0: 2 segments
# ID 50.0, Trajectory 22.0: 3 segments
# ID 51.0, Trajectory 2.0: 3 segments
# ID 51.0, Trajectory 3.0: 2 segments
# ID 51.0, Trajectory 4.0: 4 segments
# ID 51.0, Trajectory 5.0: 4 segments
# ID 51.0, Trajectory 6.0: 1 segments
# ID 51.0, Trajectory 7.0: 5 segments
# ID 51.0, Trajectory 8.0: 2 segments
# ID 51.0, Trajectory 9.0: 4 segments
# ID 51.0, Trajectory 10.0: 7 segments
# ID 51.0, Trajectory 11.0: 7 segments
# ID 51.0, Trajectory 13.0: 2 segments
# ID 51.0, Trajectory 14.0: 5 segments
# ID 51.0, Trajectory 15.0: 3 segments
# ID 51.0, Trajectory 16.0: 9 segments
# ID 51.0, Trajectory 17.0: 4 segments
# ID 51.0, Trajectory 18.0: 14 segments
# ID 51.0, Trajectory 19.0: 2 segments
# ID 51.0, Trajectory 20.0: 5 segments
# ID 51.0, Trajectory 27.0: 4 segments
# ID 51.0, Trajectory 29.0: 1 segments
# ID 51.0, Trajectory 30.0: 2 segments
# ID 51.0, Trajectory 34.0: 3 segments
# ID 52.0, Trajectory 2.0: 10 segments
# ID 52.0, Trajectory 3.0: 10 segments
# ID 52.0, Trajectory 4.0: 3 segments
# ID 52.0, Trajectory 5.0: 6 segments
# ID 52.0, Trajectory 6.0: 18 segments
# ID 52.0, Trajectory 7.0: 8 segments
# ID 52.0, Trajectory 8.0: 11 segments
# ID 52.0, Trajectory 9.0: 8 segments
# ID 52.0, Trajectory 10.0: 2 segments
# ID 52.0, Trajectory 11.0: 14 segments
# ID 52.0, Trajectory 15.0: 2 segments
# ID 52.0, Trajectory 16.0: 1 segments
# ID 52.0, Trajectory 20.0: 2 segments
# ID 52.0, Trajectory 22.0: 9 segments
# ID 52.0, Trajectory 27.0: 10 segments
# ID 52.0, Trajectory 29.0: 6 segments
# ID 52.0, Trajectory 30.0: 1 segments
# ID 52.0, Trajectory 33.0: 2 segments
# ID 53.0, Trajectory 30.0: 14 segments
# ID 55.0, Trajectory 2.0: 6 segments
# ID 55.0, Trajectory 3.0: 11 segments
# ID 55.0, Trajectory 4.0: 2 segments
# ID 55.0, Trajectory 6.0: 2 segments
# ID 55.0, Trajectory 8.0: 3 segments
# ID 55.0, Trajectory 10.0: 2 segments
# ID 55.0, Trajectory 11.0: 1 segments
# ID 55.0, Trajectory 12.0: 4 segments
# ID 55.0, Trajectory 13.0: 6 segments
# ID 55.0, Trajectory 14.0: 2 segments
# ID 55.0, Trajectory 15.0: 4 segments
# ID 55.0, Trajectory 18.0: 14 segments
# ID 55.0, Trajectory 21.0: 3 segments
# ID 55.0, Trajectory 25.0: 2 segments
# ID 57.0, Trajectory 1.0: 3 segments
# ID 57.0, Trajectory 5.0: 16 segments
# ID 57.0, Trajectory 7.0: 5 segments
# ID 57.0, Trajectory 10.0: 2 segments
# ID 57.0, Trajectory 29.0: 11 segments
# ID 57.0, Trajectory 31.0: 4 segments
# ID 58.0, Trajectory 2.0: 19 segments
# ID 58.0, Trajectory 3.0: 10 segments
# ID 58.0, Trajectory 4.0: 11 segments
# ID 58.0, Trajectory 5.0: 8 segments
# ID 58.0, Trajectory 6.0: 15 segments
# ID 58.0, Trajectory 7.0: 20 segments
# ID 58.0, Trajectory 8.0: 14 segments
# ID 58.0, Trajectory 9.0: 35 segments
# ID 58.0, Trajectory 10.0: 33 segments
# ID 58.0, Trajectory 11.0: 26 segments
# ID 58.0, Trajectory 12.0: 18 segments
# ID 58.0, Trajectory 13.0: 20 segments
# ID 58.0, Trajectory 16.0: 68 segments
# ID 62.0, Trajectory 2.0: 2 segments
# ID 62.0, Trajectory 3.0: 23 segments
# ID 62.0, Trajectory 4.0: 3 segments
# ID 62.0, Trajectory 5.0: 23 segments
# ID 62.0, Trajectory 6.0: 3 segments
# ID 62.0, Trajectory 7.0: 10 segments
# ID 62.0, Trajectory 9.0: 4 segments
# ID 62.0, Trajectory 10.0: 1 segments
# ID 62.0, Trajectory 11.0: 5 segments
# ID 62.0, Trajectory 12.0: 1 segments
# ID 62.0, Trajectory 13.0: 3 segments
# ID 62.0, Trajectory 15.0: 4 segments
# ID 62.0, Trajectory 17.0: 1 segments
# ID 62.0, Trajectory 18.0: 13 segments
# ID 62.0, Trajectory 19.0: 1 segments
# ID 64.0, Trajectory 1.0: 15 segments
# ID 64.0, Trajectory 2.0: 14 segments
# ID 64.0, Trajectory 3.0: 17 segments
# ID 64.0, Trajectory 4.0: 7 segments
# ID 64.0, Trajectory 5.0: 5 segments
# ID 64.0, Trajectory 6.0: 6 segments
# ID 64.0, Trajectory 7.0: 15 segments
# ID 64.0, Trajectory 8.0: 6 segments
# ID 64.0, Trajectory 9.0: 3 segments
# ID 64.0, Trajectory 10.0: 4 segments
# ID 64.0, Trajectory 11.0: 2 segments
# ID 64.0, Trajectory 12.0: 18 segments
# ID 64.0, Trajectory 13.0: 4 segments
# ID 64.0, Trajectory 14.0: 5 segments
# ID 64.0, Trajectory 15.0: 8 segments
# ID 64.0, Trajectory 16.0: 4 segments
# ID 64.0, Trajectory 17.0: 4 segments
# ID 66.0, Trajectory 2.0: 12 segments
# ID 66.0, Trajectory 3.0: 2 segments
# ID 66.0, Trajectory 4.0: 7 segments
# ID 66.0, Trajectory 5.0: 4 segments
# ID 66.0, Trajectory 31.0: 21 segments
# ID 66.0, Trajectory 34.0: 21 segments
# ID 68.0, Trajectory 1.0: 7 segments
# ID 68.0, Trajectory 2.0: 29 segments
# ID 68.0, Trajectory 3.0: 20 segments
# ID 68.0, Trajectory 4.0: 13 segments
# ID 68.0, Trajectory 5.0: 19 segments
# ID 68.0, Trajectory 6.0: 35 segments
# ID 68.0, Trajectory 7.0: 28 segments
# ID 68.0, Trajectory 8.0: 15 segments
# ID 68.0, Trajectory 9.0: 12 segments
# ID 68.0, Trajectory 10.0: 37 segments
# ID 68.0, Trajectory 11.0: 32 segments
# ID 68.0, Trajectory 12.0: 31 segments
# ID 68.0, Trajectory 13.0: 8 segments
# ID 71.0, Trajectory 2.0: 59 segments
# ID 71.0, Trajectory 3.0: 39 segments
# ID 71.0, Trajectory 4.0: 13 segments
# ID 71.0, Trajectory 6.0: 41 segments
# ID 71.0, Trajectory 8.0: 26 segments
# ID 71.0, Trajectory 9.0: 52 segments
# ID 71.0, Trajectory 10.0: 59 segments
# ID 72.0, Trajectory 1.0: 11 segments
# ID 72.0, Trajectory 2.0: 30 segments
# ID 72.0, Trajectory 3.0: 29 segments
# ID 72.0, Trajectory 4.0: 17 segments
# ID 72.0, Trajectory 5.0: 9 segments
# ID 72.0, Trajectory 6.0: 8 segments
# ID 72.0, Trajectory 7.0: 14 segments
# ID 72.0, Trajectory 8.0: 15 segments
# ID 72.0, Trajectory 9.0: 13 segments
# ID 72.0, Trajectory 10.0: 13 segments
# ID 72.0, Trajectory 11.0: 22 segments
# ID 72.0, Trajectory 12.0: 15 segments
# ID 72.0, Trajectory 13.0: 15 segments
# ID 72.0, Trajectory 14.0: 15 segments
# ID 72.0, Trajectory 15.0: 37 segments
# ID 72.0, Trajectory 16.0: 28 segments
# ID 72.0, Trajectory 17.0: 21 segments
# ID 74.0, Trajectory 2.0: 35 segments
# ID 74.0, Trajectory 3.0: 14 segments
# ID 74.0, Trajectory 4.0: 11 segments
# ID 74.0, Trajectory 5.0: 14 segments
# ID 74.0, Trajectory 6.0: 16 segments
# ID 74.0, Trajectory 7.0: 15 segments
# ID 74.0, Trajectory 8.0: 17 segments
# ID 74.0, Trajectory 9.0: 6 segments
# ID 74.0, Trajectory 10.0: 10 segments
# ID 74.0, Trajectory 11.0: 16 segments
# ID 74.0, Trajectory 12.0: 9 segments
# ID 74.0, Trajectory 13.0: 11 segments
# ID 74.0, Trajectory 14.0: 7 segments
# ID 74.0, Trajectory 15.0: 11 segments
# ID 74.0, Trajectory 16.0: 8 segments
# ID 74.0, Trajectory 17.0: 18 segments
# ID 74.0, Trajectory 18.0: 25 segments
# ID 74.0, Trajectory 19.0: 7 segments
# ID 75.0, Trajectory 2.0: 9 segments
# ID 75.0, Trajectory 4.0: 4 segments
# ID 75.0, Trajectory 6.0: 8 segments
# ID 75.0, Trajectory 7.0: 1 segments
# ID 75.0, Trajectory 10.0: 2 segments
# ID 75.0, Trajectory 14.0: 2 segments
# ID 75.0, Trajectory 20.0: 9 segments
# ID 75.0, Trajectory 23.0: 1 segments
# ID 75.0, Trajectory 30.0: 3 segments
# ID 78.0, Trajectory 2.0: 10 segments
# ID 78.0, Trajectory 3.0: 4 segments
# ID 78.0, Trajectory 4.0: 5 segments
# ID 78.0, Trajectory 5.0: 8 segments
# ID 78.0, Trajectory 6.0: 11 segments
# ID 78.0, Trajectory 7.0: 6 segments
# ID 78.0, Trajectory 8.0: 13 segments
# ID 78.0, Trajectory 9.0: 44 segments
# ID 78.0, Trajectory 10.0: 190 segments
# ID 79.0, Trajectory 28.0: 2 segments
# ID 81.0, Trajectory 7.0: 5 segments
# ID 81.0, Trajectory 8.0: 4 segments
# ID 81.0, Trajectory 15.0: 5 segments
# ID 81.0, Trajectory 24.0: 5 segments
# ID 135.0, Trajectory 2.0: 10 segments
# ID 135.0, Trajectory 3.0: 4 segments
# ID 135.0, Trajectory 4.0: 1 segments
# ID 135.0, Trajectory 5.0: 1 segments
# ID 135.0, Trajectory 6.0: 3 segments
# ID 135.0, Trajectory 7.0: 9 segments
# ID 135.0, Trajectory 8.0: 2 segments
# ID 135.0, Trajectory 9.0: 5 segments
# ID 135.0, Trajectory 10.0: 10 segments
# ID 135.0, Trajectory 11.0: 9 segments
# ID 135.0, Trajectory 12.0: 7 segments
# ID 135.0, Trajectory 13.0: 6 segments
# ID 135.0, Trajectory 14.0: 13 segments
# ID 135.0, Trajectory 15.0: 3 segments
# ID 135.0, Trajectory 16.0: 9 segments
# ID 135.0, Trajectory 17.0: 13 segments
# ID 135.0, Trajectory 18.0: 11 segments
# ID 135.0, Trajectory 19.0: 7 segments
# ID 135.0, Trajectory 20.0: 3 segments
# ID 135.0, Trajectory 21.0: 3 segments
# ID 135.0, Trajectory 22.0: 3 segments
# ID 135.0, Trajectory 23.0: 6 segments
# ID 135.0, Trajectory 25.0: 1 segments
# ID 138.0, Trajectory 1.0: 124 segments
# ID 138.0, Trajectory 2.0: 5 segments
# ID 138.0, Trajectory 3.0: 5 segments
# ID 138.0, Trajectory 4.0: 2 segments
# ID 138.0, Trajectory 5.0: 7 segments
# ID 138.0, Trajectory 6.0: 2 segments
# ID 138.0, Trajectory 7.0: 53 segments
# ID 138.0, Trajectory 8.0: 24 segments
# ID 138.0, Trajectory 9.0: 6 segments
# ID 138.0, Trajectory 10.0: 44 segments
# ID 138.0, Trajectory 11.0: 2 segments
# ID 138.0, Trajectory 16.0: 41 segments
# ID 139.0, Trajectory 3.0: 7 segments
# ID 139.0, Trajectory 4.0: 5 segments
# ID 139.0, Trajectory 5.0: 2 segments
# ID 139.0, Trajectory 10.0: 1 segments
# ID 139.0, Trajectory 11.0: 3 segments
# ID 139.0, Trajectory 15.0: 2 segments
# ID 139.0, Trajectory 16.0: 11 segments
# ID 139.0, Trajectory 17.0: 4 segments
# ID 139.0, Trajectory 18.0: 4 segments
# ID 139.0, Trajectory 19.0: 9 segments
# ID 139.0, Trajectory 22.0: 4 segments
# ID 139.0, Trajectory 23.0: 10 segments
# ID 139.0, Trajectory 24.0: 7 segments
# ID 139.0, Trajectory 25.0: 4 segments
# ID 140.0, Trajectory 2.0: 19 segments
# ID 140.0, Trajectory 3.0: 18 segments
# ID 140.0, Trajectory 4.0: 21 segments
# ID 140.0, Trajectory 5.0: 10 segments
# ID 140.0, Trajectory 6.0: 19 segments
# ID 140.0, Trajectory 7.0: 20 segments
# ID 140.0, Trajectory 8.0: 20 segments
# ID 140.0, Trajectory 9.0: 26 segments
# ID 140.0, Trajectory 10.0: 19 segments
# ID 140.0, Trajectory 11.0: 19 segments
# ID 140.0, Trajectory 12.0: 37 segments
# ID 140.0, Trajectory 13.0: 13 segments
# ID 140.0, Trajectory 14.0: 14 segments
# ID 140.0, Trajectory 15.0: 9 segments
# ID 140.0, Trajectory 16.0: 7 segments
# ID 140.0, Trajectory 17.0: 5 segments
# ID 142.0, Trajectory 2.0: 8 segments
# ID 142.0, Trajectory 3.0: 2 segments
# ID 142.0, Trajectory 4.0: 3 segments
# ID 142.0, Trajectory 7.0: 1 segments
# ID 142.0, Trajectory 8.0: 1 segments
# ID 142.0, Trajectory 9.0: 2 segments
# ID 142.0, Trajectory 10.0: 6 segments
# ID 142.0, Trajectory 13.0: 2 segments
# ID 142.0, Trajectory 15.0: 8 segments
# ID 142.0, Trajectory 17.0: 2 segments
# ID 142.0, Trajectory 18.0: 8 segments
# ID 142.0, Trajectory 20.0: 2 segments
# ID 142.0, Trajectory 21.0: 3 segments
# ID 142.0, Trajectory 22.0: 9 segments
# ID 142.0, Trajectory 23.0: 6 segments
# ID 142.0, Trajectory 25.0: 7 segments
# ID 146.0, Trajectory 2.0: 17 segments
# ID 146.0, Trajectory 3.0: 22 segments
# ID 146.0, Trajectory 4.0: 10 segments
# ID 146.0, Trajectory 5.0: 34 segments
# ID 146.0, Trajectory 6.0: 45 segments
# ID 146.0, Trajectory 7.0: 17 segments
# ID 146.0, Trajectory 8.0: 19 segments
# ID 146.0, Trajectory 9.0: 56 segments
# ID 146.0, Trajectory 10.0: 16 segments
# ID 146.0, Trajectory 11.0: 43 segments
# ID 146.0, Trajectory 12.0: 12 segments
# ID 147.0, Trajectory 1.0: 6 segments
# ID 147.0, Trajectory 2.0: 2 segments
# ID 147.0, Trajectory 3.0: 15 segments
# ID 147.0, Trajectory 4.0: 39 segments
# ID 147.0, Trajectory 5.0: 3 segments
# ID 147.0, Trajectory 6.0: 1 segments
# ID 147.0, Trajectory 7.0: 3 segments
# ID 147.0, Trajectory 8.0: 4 segments
# ID 147.0, Trajectory 9.0: 7 segments
# ID 147.0, Trajectory 10.0: 18 segments
# ID 147.0, Trajectory 11.0: 14 segments
# ID 147.0, Trajectory 12.0: 20 segments
# ID 147.0, Trajectory 13.0: 4 segments
# ID 147.0, Trajectory 14.0: 22 segments
# ID 147.0, Trajectory 15.0: 8 segments
# ID 147.0, Trajectory 16.0: 4 segments
# ID 147.0, Trajectory 17.0: 8 segments
# ID 147.0, Trajectory 19.0: 11 segments
# ID 148.0, Trajectory 2.0: 15 segments
# ID 148.0, Trajectory 3.0: 9 segments
# ID 148.0, Trajectory 4.0: 11 segments
# ID 148.0, Trajectory 5.0: 11 segments
# ID 148.0, Trajectory 6.0: 14 segments
# ID 148.0, Trajectory 7.0: 8 segments
# ID 148.0, Trajectory 8.0: 8 segments
# ID 148.0, Trajectory 9.0: 3 segments
# ID 148.0, Trajectory 11.0: 2 segments
# ID 148.0, Trajectory 12.0: 1 segments
# ID 148.0, Trajectory 15.0: 5 segments
# ID 148.0, Trajectory 17.0: 1 segments
# ID 148.0, Trajectory 18.0: 4 segments
# ID 148.0, Trajectory 19.0: 7 segments
# ID 148.0, Trajectory 20.0: 4 segments
# ID 148.0, Trajectory 21.0: 2 segments
# ID 148.0, Trajectory 22.0: 48 segments
# ID 148.0, Trajectory 23.0: 12 segments
# ID 155.0, Trajectory 1.0: 20 segments
# ID 155.0, Trajectory 2.0: 5 segments
# ID 155.0, Trajectory 7.0: 7 segments
# ID 155.0, Trajectory 8.0: 3 segments
# ID 155.0, Trajectory 9.0: 3 segments
# ID 155.0, Trajectory 12.0: 1 segments
# ID 155.0, Trajectory 14.0: 2 segments
# ID 156.0, Trajectory 2.0: 2 segments
# ID 156.0, Trajectory 4.0: 5 segments
# ID 156.0, Trajectory 5.0: 4 segments
# ID 156.0, Trajectory 7.0: 3 segments
# ID 156.0, Trajectory 11.0: 2 segments
# ID 156.0, Trajectory 12.0: 3 segments
# ID 156.0, Trajectory 13.0: 2 segments
# ID 156.0, Trajectory 14.0: 5 segments
# ID 156.0, Trajectory 15.0: 4 segments
# ID 156.0, Trajectory 19.0: 1 segments
# ID 156.0, Trajectory 21.0: 3 segments
# ID 156.0, Trajectory 22.0: 2 segments
# ID 156.0, Trajectory 26.0: 3 segments
# ID 158.0, Trajectory 2.0: 16 segments
# ID 158.0, Trajectory 3.0: 15 segments
# ID 158.0, Trajectory 4.0: 17 segments
# ID 158.0, Trajectory 5.0: 14 segments
# ID 158.0, Trajectory 6.0: 12 segments
# ID 158.0, Trajectory 7.0: 12 segments
# ID 158.0, Trajectory 8.0: 26 segments
# ID 158.0, Trajectory 9.0: 11 segments
# ID 158.0, Trajectory 10.0: 6 segments
# ID 158.0, Trajectory 12.0: 4 segments
# ID 158.0, Trajectory 13.0: 1 segments
# ID 158.0, Trajectory 14.0: 3 segments
# ID 158.0, Trajectory 15.0: 1 segments
# ID 158.0, Trajectory 16.0: 22 segments
# ID 158.0, Trajectory 17.0: 4 segments
# ID 158.0, Trajectory 18.0: 2 segments
# ID 158.0, Trajectory 19.0: 7 segments
# ID 163.0, Trajectory 2.0: 22 segments
# ID 163.0, Trajectory 3.0: 13 segments
# ID 163.0, Trajectory 4.0: 21 segments
# ID 163.0, Trajectory 5.0: 11 segments
# ID 163.0, Trajectory 6.0: 12 segments
# ID 163.0, Trajectory 7.0: 14 segments
# ID 163.0, Trajectory 8.0: 21 segments
# ID 163.0, Trajectory 9.0: 23 segments
# ID 163.0, Trajectory 10.0: 16 segments
# ID 163.0, Trajectory 11.0: 55 segments
# ID 163.0, Trajectory 12.0: 25 segments
# ID 163.0, Trajectory 13.0: 23 segments
# ID 163.0, Trajectory 14.0: 2 segments
# ID 163.0, Trajectory 15.0: 6 segments
# ID 164.0, Trajectory 1.0: 14 segments
# ID 164.0, Trajectory 2.0: 22 segments
# ID 164.0, Trajectory 3.0: 8 segments
# ID 164.0, Trajectory 4.0: 9 segments
# ID 164.0, Trajectory 5.0: 12 segments
# ID 164.0, Trajectory 6.0: 27 segments
# ID 164.0, Trajectory 7.0: 9 segments
# ID 164.0, Trajectory 8.0: 8 segments
# ID 164.0, Trajectory 9.0: 22 segments
# ID 164.0, Trajectory 10.0: 53 segments
# ID 164.0, Trajectory 11.0: 8 segments
# ID 164.0, Trajectory 12.0: 17 segments
# ID 164.0, Trajectory 13.0: 5 segments
# ID 164.0, Trajectory 14.0: 11 segments
# ID 164.0, Trajectory 15.0: 9 segments
# ID 164.0, Trajectory 16.0: 8 segments
# ID 164.0, Trajectory 17.0: 9 segments
# ID 165.0, Trajectory 1.0: 1 segments
# ID 165.0, Trajectory 2.0: 3 segments
# ID 165.0, Trajectory 3.0: 2 segments
# ID 165.0, Trajectory 4.0: 5 segments
# ID 165.0, Trajectory 5.0: 8 segments
# ID 165.0, Trajectory 6.0: 15 segments
# ID 165.0, Trajectory 7.0: 14 segments
# ID 165.0, Trajectory 8.0: 2 segments
# ID 165.0, Trajectory 9.0: 4 segments
# ID 165.0, Trajectory 10.0: 3 segments
# ID 165.0, Trajectory 11.0: 8 segments
# ID 165.0, Trajectory 12.0: 1 segments
# ID 165.0, Trajectory 13.0: 4 segments
# ID 165.0, Trajectory 14.0: 4 segments
# ID 165.0, Trajectory 16.0: 1 segments
# ID 165.0, Trajectory 17.0: 2 segments
# ID 165.0, Trajectory 18.0: 2 segments
# ID 168.0, Trajectory 2.0: 14 segments
# ID 168.0, Trajectory 3.0: 12 segments
# ID 168.0, Trajectory 4.0: 11 segments
# ID 168.0, Trajectory 5.0: 14 segments
# ID 168.0, Trajectory 6.0: 16 segments
# ID 168.0, Trajectory 7.0: 30 segments
# ID 168.0, Trajectory 8.0: 16 segments
# ID 168.0, Trajectory 9.0: 27 segments
# ID 168.0, Trajectory 10.0: 27 segments
# ID 168.0, Trajectory 11.0: 36 segments
# ID 168.0, Trajectory 12.0: 5 segments
# ID 168.0, Trajectory 13.0: 6 segments
# ID 168.0, Trajectory 14.0: 10 segments
# ID 168.0, Trajectory 15.0: 6 segments
# ID 168.0, Trajectory 16.0: 13 segments
# ID 168.0, Trajectory 17.0: 9 segments
# ID 170.0, Trajectory 2.0: 4 segments
# ID 170.0, Trajectory 3.0: 7 segments
# ID 170.0, Trajectory 5.0: 1 segments
# ID 170.0, Trajectory 6.0: 4 segments
# ID 170.0, Trajectory 7.0: 7 segments
# ID 170.0, Trajectory 8.0: 3 segments
# ID 170.0, Trajectory 9.0: 4 segments
# ID 170.0, Trajectory 10.0: 4 segments
# ID 170.0, Trajectory 12.0: 5 segments
# ID 170.0, Trajectory 13.0: 2 segments
# ID 170.0, Trajectory 14.0: 1 segments
# ID 170.0, Trajectory 21.0: 1 segments
# ID 170.0, Trajectory 23.0: 3 segments
# ID 170.0, Trajectory 27.0: 2 segments
# ID 173.0, Trajectory 2.0: 2 segments
# ID 173.0, Trajectory 4.0: 10 segments
# ID 173.0, Trajectory 7.0: 5 segments
# ID 173.0, Trajectory 8.0: 5 segments
# ID 173.0, Trajectory 9.0: 5 segments
# ID 173.0, Trajectory 10.0: 7 segments
# ID 173.0, Trajectory 11.0: 2 segments
# ID 173.0, Trajectory 12.0: 7 segments
# ID 173.0, Trajectory 13.0: 9 segments
# ID 173.0, Trajectory 14.0: 2 segments
# ID 173.0, Trajectory 17.0: 1 segments
# ID 173.0, Trajectory 18.0: 3 segments
# ID 173.0, Trajectory 19.0: 4 segments
# ID 173.0, Trajectory 22.0: 1 segments
# ID 173.0, Trajectory 23.0: 2 segments
# ID 173.0, Trajectory 24.0: 1 segments
# ID 173.0, Trajectory 25.0: 2 segments
# ID 173.0, Trajectory 26.0: 2 segments
# ID 175.0, Trajectory 1.0: 9 segments
# ID 175.0, Trajectory 2.0: 2 segments
# ID 175.0, Trajectory 3.0: 8 segments
# ID 175.0, Trajectory 4.0: 13 segments
# ID 175.0, Trajectory 5.0: 34 segments
# ID 175.0, Trajectory 6.0: 31 segments
# ID 175.0, Trajectory 7.0: 11 segments
# ID 175.0, Trajectory 8.0: 19 segments
# ID 175.0, Trajectory 9.0: 11 segments
# ID 175.0, Trajectory 10.0: 17 segments
# ID 175.0, Trajectory 12.0: 2 segments
# ID 175.0, Trajectory 13.0: 83 segments
# ID 180.0, Trajectory 2.0: 2 segments
# ID 180.0, Trajectory 14.0: 1 segments
# ID 180.0, Trajectory 30.0: 27 segments
# ID 181.0, Trajectory 1.0: 28 segments
# ID 181.0, Trajectory 2.0: 5 segments
# ID 181.0, Trajectory 4.0: 1 segments
# ID 181.0, Trajectory 5.0: 8 segments
# ID 181.0, Trajectory 6.0: 2 segments
# ID 181.0, Trajectory 7.0: 5 segments
# ID 181.0, Trajectory 12.0: 7 segments
# ID 181.0, Trajectory 24.0: 1 segments
# ID 184.0, Trajectory 1.0: 1 segments
# ID 184.0, Trajectory 2.0: 16 segments
# ID 184.0, Trajectory 3.0: 12 segments
# ID 184.0, Trajectory 4.0: 4 segments
# ID 184.0, Trajectory 5.0: 3 segments
# ID 184.0, Trajectory 8.0: 6 segments
# ID 184.0, Trajectory 10.0: 2 segments
# ID 184.0, Trajectory 13.0: 2 segments
# ID 227.0, Trajectory 1.0: 84 segments
# ID 227.0, Trajectory 7.0: 2 segments
# ID 230.0, Trajectory 2.0: 2 segments
# ID 230.0, Trajectory 4.0: 3 segments
# ID 230.0, Trajectory 8.0: 3 segments
# ID 230.0, Trajectory 9.0: 4 segments
# ID 230.0, Trajectory 10.0: 2 segments
# ID 230.0, Trajectory 11.0: 3 segments
# ID 230.0, Trajectory 12.0: 4 segments
# ID 241.0, Trajectory 2.0: 25 segments
# ID 241.0, Trajectory 3.0: 81 segments
# ID 241.0, Trajectory 4.0: 11 segments
# ID 241.0, Trajectory 5.0: 16 segments
# ID 242.0, Trajectory 2.0: 16 segments
# ID 242.0, Trajectory 5.0: 3 segments
# ID 242.0, Trajectory 7.0: 3 segments
# ID 242.0, Trajectory 8.0: 3 segments
# ID 242.0, Trajectory 9.0: 1 segments
# ID 244.0, Trajectory 2.0: 6 segments
# ID 244.0, Trajectory 3.0: 12 segments
# ID 244.0, Trajectory 4.0: 16 segments
# ID 244.0, Trajectory 5.0: 8 segments
# ID 245.0, Trajectory 2.0: 9 segments
# ID 245.0, Trajectory 3.0: 5 segments
# ID 245.0, Trajectory 15.0: 1 segments
# ID 245.0, Trajectory 16.0: 2 segments
# ID 245.0, Trajectory 19.0: 6 segments
# ID 250.0, Trajectory 2.0: 18 segments
# ID 250.0, Trajectory 3.0: 2 segments
# ID 250.0, Trajectory 10.0: 5 segments
# ID 250.0, Trajectory 11.0: 2 segments
# ID 250.0, Trajectory 12.0: 3 segments
# ID 250.0, Trajectory 13.0: 2 segments
# ID 250.0, Trajectory 16.0: 5 segments
# ID 252.0, Trajectory 8.0: 1 segments
# ID 252.0, Trajectory 11.0: 4 segments
# ID 252.0, Trajectory 12.0: 7 segments
# ID 252.0, Trajectory 18.0: 1 segments
# ID 253.0, Trajectory 1.0: 149 segments
# ID 253.0, Trajectory 2.0: 33 segments
# ID 253.0, Trajectory 3.0: 32 segments
# ID 253.0, Trajectory 4.0: 21 segments
# ID 253.0, Trajectory 5.0: 6 segments
# ID 253.0, Trajectory 6.0: 13 segments
# ID 253.0, Trajectory 7.0: 24 segments
# ID 254.0, Trajectory 2.0: 1 segments
# ID 254.0, Trajectory 4.0: 1 segments
# ID 254.0, Trajectory 5.0: 8 segments
# ID 255.0, Trajectory 2.0: 31 segments
# ID 255.0, Trajectory 3.0: 23 segments
# ID 255.0, Trajectory 4.0: 26 segments
# ID 255.0, Trajectory 5.0: 70 segments
# ID 255.0, Trajectory 6.0: 66 segments
# ID 255.0, Trajectory 7.0: 56 segments
# ID 256.0, Trajectory 2.0: 82 segments
# ID 256.0, Trajectory 3.0: 91 segments
# ID 256.0, Trajectory 4.0: 26 segments
# ID 256.0, Trajectory 5.0: 23 segments
# ID 256.0, Trajectory 6.0: 13 segments
# ID 273.0, Trajectory 2.0: 9 segments
# ID 273.0, Trajectory 5.0: 4 segments
# ID 273.0, Trajectory 6.0: 10 segments
# ID 273.0, Trajectory 7.0: 3 segments
# ID 273.0, Trajectory 8.0: 12 segments
# ID 273.0, Trajectory 9.0: 5 segments
# ID 273.0, Trajectory 10.0: 3 segments
# ID 274.0, Trajectory 2.0: 11 segments
# ID 274.0, Trajectory 8.0: 6 segments
# ID 274.0, Trajectory 9.0: 10 segments
# ID 274.0, Trajectory 13.0: 4 segments
# ID 276.0, Trajectory 2.0: 21 segments
# ID 276.0, Trajectory 3.0: 1 segments
# ID 276.0, Trajectory 5.0: 3 segments
# ID 276.0, Trajectory 6.0: 14 segments
# ID 276.0, Trajectory 7.0: 3 segments
# ID 276.0, Trajectory 8.0: 3 segments
# ID 276.0, Trajectory 9.0: 2 segments
# ID 276.0, Trajectory 10.0: 28 segments
# ID 278.0, Trajectory 1.0: 6 segments
# ID 278.0, Trajectory 6.0: 8 segments
# ID 280.0, Trajectory 2.0: 15 segments
# ID 280.0, Trajectory 3.0: 3 segments
# ID 280.0, Trajectory 4.0: 10 segments
# ID 280.0, Trajectory 5.0: 2 segments
# ID 280.0, Trajectory 6.0: 8 segments
# ID 280.0, Trajectory 7.0: 12 segments
# ID 280.0, Trajectory 8.0: 2 segments
# ID 280.0, Trajectory 9.0: 3 segments
# ID 280.0, Trajectory 10.0: 14 segments
# ID 281.0, Trajectory 2.0: 2 segments
# ID 281.0, Trajectory 3.0: 2 segments
# ID 282.0, Trajectory 2.0: 49 segments
# ID 282.0, Trajectory 8.0: 2 segments
# ID 282.0, Trajectory 9.0: 10 segments
# ID 282.0, Trajectory 10.0: 1 segments
# ID 282.0, Trajectory 12.0: 2 segments
# ID 282.0, Trajectory 13.0: 3 segments
# ID 283.0, Trajectory 2.0: 2 segments
# ID 283.0, Trajectory 7.0: 6 segments
# ID 283.0, Trajectory 8.0: 5 segments
# ID 283.0, Trajectory 9.0: 4 segments
# ID 283.0, Trajectory 10.0: 3 segments
# ID 283.0, Trajectory 11.0: 1 segments
# ID 283.0, Trajectory 12.0: 7 segments
# ID 283.0, Trajectory 13.0: 6 segments
# ID 283.0, Trajectory 15.0: 3 segments
# ID 283.0, Trajectory 16.0: 4 segments
# ID 283.0, Trajectory 17.0: 2 segments
# ID 287.0, Trajectory 1.0: 3 segments
# ID 287.0, Trajectory 2.0: 7 segments
# TOTAL SEGMENTS GENERATED: 7385

# %%
data = []
total_segments = 0

for (pid, traj_id), group in grouped:
    group = group.sort_values(by='Time')

    if group.shape[0] < traj_length:
        continue

    cluster = int(group['Cluster'].iloc[0])

    traj_np = group[trajectory_features].values
    up_np    = group['Up'].values
    right_np = group['Right'].values
    down_np  = group['Down'].values
    left_np  = group['Left'].values

    for start in range(len(traj_np) - traj_length + 1):
        segment = traj_np[start:start + traj_length]
        up_seg    = up_np[start:start + traj_length]
        right_seg = right_np[start:start + traj_length]
        down_seg  = down_np[start:start + traj_length]
        left_seg  = left_np[start:start + traj_length]

        sample = {
            'trajectory': torch.tensor(segment, dtype=torch.float32),  
            'up':    torch.tensor(up_seg, dtype=torch.float32),        
            'right': torch.tensor(right_seg, dtype=torch.float32),
            'down':  torch.tensor(down_seg, dtype=torch.float32),
            'left':  torch.tensor(left_seg, dtype=torch.float32),
            'cluster': cluster,
            'id': int(pid)
        }

        data.append(sample)


torch.save(data, "social_lstm_structured.pt")
print(f"Saved {len(data)} trajectory segments.")

# train and test
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# 保存为两个 pt 文件
torch.save(train_data, "train_social_lstm.pt")
torch.save(test_data, "test_social_lstm.pt")

print(f"Train: {len(train_data)} samples, Test: {len(test_data)} samples.")
# Out:
# Saved 7385 trajectory segments.
# Train: 5908 samples, Test: 1477 samples.

# %%
from collections import Counter
labels = [d['cluster'] for d in data]
print(Counter(labels))
# Out:
# Counter({1: 4610, 2: 2775})

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

def evaluate_classifier(model, test_data):
    y_true = []
    y_pred = []

    model.eval()
    with torch.no_grad():
        for sample in test_data:
            traj = sample['trajectory'].unsqueeze(0)  # [1, 15, D]
            neighbors = torch.stack([
                sample['up'], sample['right'],
                sample['down'], sample['left']
            ], dim=-1).unsqueeze(0)  # [1, 15, 4]

            label = sample['cluster']
            logits = model(traj, neighbors)
            pred = logits.argmax(dim=1).item()

            y_true.append(label)
            y_pred.append(pred)

    print("Accuracy:", accuracy_score(y_true, y_pred))
    print("Classification Report:")
    print(classification_report(y_true, y_pred, digits=3))
    print(" Confusion Matrix:")
    print(confusion_matrix(y_true, y_pred))
